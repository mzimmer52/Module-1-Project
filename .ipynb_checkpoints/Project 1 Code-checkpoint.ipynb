# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Max Zimmerman
# * Student pace: self paced
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# IMPORTING LIBRARIES
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_context("talk")

# %%
#plt.style.available

# %%
#ls

# %%
budgets = pd.read_csv("data/tn.movie_budgets.csv.gz")
budgets["production_budget"].sort_values(ascending=False)

#Getting rid of commas to turn numbers into ints, as well as dividing both budget and income by a million for readability
budgets["production_budget"] = budgets["production_budget"].apply(lambda x: x[1:]).str.replace(",", "").astype(int)/1000000
budgets["worldwide_gross"] = budgets["worldwide_gross"].apply(lambda x: x[1:]).str.replace(",", "").astype(int)/1000000  

#ROI DEFINED HERE ARE GROSS REVENUE DIVIDED BY BUDGET
budgets["ROI"] = budgets["worldwide_gross"]/budgets["production_budget"]
budgets.sort_values("ROI", ascending = False)

#plotting budget vs. revenue
with plt.style.context("fivethirtyeight"):
    fig = sns.regplot(x = "production_budget", y = "worldwide_gross", data = budgets);
    plt.xlabel("Budget (Millions $)")
    plt.ylabel("Revenue (Millions $)")
    plt.title("Budget vs. Revenue")
    plt.show(fig)

# setting index to movie name, ROI in descending order
new = budgets.set_index("movie").sort_values("ROI", ascending = False).head()


new.drop("domestic_gross", axis = 1).iloc[1:]
# Out:
#                          id  release_date  production_budget  worldwide_gross  \
# movie
# Mad Max                  14  Mar 21, 1980               0.20        99.750000
# Paranormal Activity      93  Sep 25, 2009               0.45       194.183034
# The Gallows              80  Jul 10, 2015               0.10        41.656474
# The Blair Witch Project   7  Jul 14, 1999               0.60       248.300000
#
#                                 ROI
# movie
# Mad Max                  498.750000
# Paranormal Activity      431.517853
# The Gallows              416.564740
# The Blair Witch Project  413.833333

# %% [markdown]
# Microsoft should take the time to study the above movies given their impressive return on investment. Each of them made over 400 times the money they invested! They should also get in touch with each movie's director and production team to go over what most of the budget money was allocated towards (advertising, special effects, etc.) Microsoft should also not be afraid of going a little over their budget, as in most cases, movies with higher budgets tended to make more money.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 


title_basics = pd.read_csv("data/imdb.title.basics.csv.gz")
title_basics.rename(columns={"primary_title": "movie"}, inplace=True)
title_ratings = pd.read_csv("data/imdb.title.ratings.csv.gz")
#merging two datasets based on the column "movie"
big_df = pd.merge(title_ratings, title_basics)
#Sorting df by number of votes, then deleting any rows with less than 100,000 votes and then sorting by average rating
big_df.sort_values("numvotes", ascending = False, inplace = True)
big_df = big_df.loc[big_df["numvotes"] > 100000].sort_values("averagerating", ascending = False)
big_df["runtime_minutes"] = big_df["runtime_minutes"].astype("float")
big_df.dropna(subset = ["runtime_minutes"], inplace = True)
big_df.head()
big_df
#sns.regplot(data=df, x="Run Time", y="Gross");
with plt.style.context("dark_background"):
    plt.figure(figsize = (12,6))
    fig = sns.regplot(x="runtime_minutes", y="averagerating", data=big_df);
    plt.xlim(70, 200);
    plt.xlabel("Runtime in Minutes");
    plt.ylabel("Average Rating out of 10");
    plt.title("Runtime vs. Average Rating");
    plt.show(fig)
    sns.boxplot(big_df["runtime_minutes"])

# %% [markdown]
# Microsoft should not be afraid to create a longer movie, but should keep in mind that the average runtime for most popular movies was between 110 and 130 minutes.

# %%
big_df
#Main point of code below is to find average ratings for specific runtime timespans, and then to see how accurate
#these findings are by seeing how many movies also fall in this runtime range
# Out:
#           tconst  averagerating  numvotes                              movie  \
# 9643   tt5813916            9.3    100568                    The Mountain II
# 63498  tt1375666            8.8   1841066                          Inception
# 59785  tt4154796            8.8    441135                  Avengers: Endgame
# 24920  tt0816692            8.6   1299334                       Interstellar
# 33441  tt4633694            8.5    210869  Spider-Man: Into the Spider-Verse
# ...          ...            ...       ...                                ...
# 71702  tt1815862            4.8    181687                        After Earth
# 12347  tt1071875            4.3    103608   Ghost Rider: Spirit of Vengeance
# 71454  tt1502712            4.3    140148                     Fantastic Four
# 72563  tt0938283            4.1    137734                 The Last Airbender
# 39686  tt2322441            4.1    279126               Fifty Shades of Grey
#
#                           original_title  start_year  runtime_minutes  \
# 9643                              Dag II        2016            135.0
# 63498                          Inception        2010            148.0
# 59785                  Avengers: Endgame        2019            181.0
# 24920                       Interstellar        2014            169.0
# 33441  Spider-Man: Into the Spider-Verse        2018            117.0
# ...                                  ...         ...              ...
# 71702                        After Earth        2013            100.0
# 12347   Ghost Rider: Spirit of Vengeance        2011             96.0
# 71454                     Fantastic Four        2015            100.0
# 72563                 The Last Airbender        2010            103.0
# 39686               Fifty Shades of Grey        2015            125.0
#
#                            genres
# 9643             Action,Drama,War
# 63498     Action,Adventure,Sci-Fi
# 59785     Action,Adventure,Sci-Fi
# 24920      Adventure,Drama,Sci-Fi
# 33441  Action,Adventure,Animation
# ...                           ...
# 71702      Action,Adventure,Drama
# 12347     Action,Fantasy,Thriller
# 71454      Action,Adventure,Drama
# 72563     Action,Adventure,Family
# 39686      Drama,Romance,Thriller
#
# [618 rows x 8 columns]

# %%
#mean average rating from runtimes 80 to 100 min
big_df[(big_df['runtime_minutes']>= 80 ) & (big_df['runtime_minutes']<100)]["averagerating"].mean()
# Out:
# 6.664130434782609

# %%
#amount of movies with runtimes between 80 and 100 min
big_df[(big_df['runtime_minutes']>= 80 ) & (big_df['runtime_minutes']<100)]["averagerating"].count()
# Out:
# 92

# %%
#mean average rating from runtimes 100 to 120 min
big_df[(big_df['runtime_minutes']>= 100 ) & (big_df['runtime_minutes']< 120)]["averagerating"].mean()
# Out:
# 6.837414965986394

# %%
#amount of movies with runtimes between 100 and 120 min
big_df[(big_df['runtime_minutes']>= 100 ) & (big_df['runtime_minutes']< 120)]["averagerating"].count()
# Out:
# 294

# %%
#mean average rating from runtimes 120 to 140 min
big_df[(big_df['runtime_minutes']>= 120 ) & (big_df['runtime_minutes']< 140)]["averagerating"].mean()
# Out:
# 7.116071428571432

# %%
#amount of movies with runtimes between 120 and 140 min
big_df[(big_df['runtime_minutes']>= 120 ) & (big_df['runtime_minutes']< 140)]["averagerating"].count()
# Out:
# 168

# %%
#mean average rating from runtimes 140 to 160 min
big_df[(big_df['runtime_minutes']>= 140 ) & (big_df['runtime_minutes']< 160)]["averagerating"].mean()
# Out:
# 7.368000000000003

# %%
#amount of movies with runtimes between 140 and 160 min
big_df[(big_df['runtime_minutes']>= 140 ) & (big_df['runtime_minutes']< 160)]["averagerating"].count()
# Out:
# 50

# %% [markdown]
# Average rating goes up as runtime goes up, however there is also not as much data for either short or long movies. Most of the movies lie in between the runtimes of 100 to 140 minutes.

# %%
#mean average rating from runtimes over 160 min
big_df[(big_df['runtime_minutes']>= 160 )]["averagerating"].mean()
# Out:
# 7.942857142857143

# %%
#amount of movies with runtimes over 160 min
big_df[(big_df['runtime_minutes']>= 160 )]["averagerating"].count()
# Out:
# 14

# %%
big_df["genres"].nunique()
#getting genres from top 100 rated movies
big_df.iloc[:100]["genres"].map(lambda x: x.split())
big_df["genres"][:8]
#creating dictionary to keep track of genre counts, if movie has multiple genres it still counts each movie as 1
new = big_df.iloc[:100]["genres"].str.split(',')
dic = {}         
for i in new:
    for y in i:
        if y not in dic:
            dic[y] = 1
        else:
            dic[y] += 1

#sort the dictionary keys so bar graph will look better
dic2 = dict(sorted(dic.items(), key=lambda item: item[1]))
with plt.style.context("bmh"):
    plt.figure(figsize=(16, 12))
    plt.xticks(rotation=45)
    plt.bar(list(dic2.keys()), dic2.values(), color='g')
    plt.title("Most Popular Genres");
    plt.show()

#Out of top-100 rated movies (all with above 100,000 ratings), finding most popular genres
#if movie has more than one genre, each genre is still counted as 1

# %% [markdown]
# Microsoft should highly consider trending towards an action, adventure, or drama movie. Out of the highest rated and most rated movies, these types of movies consistently came out on top.

# %%
from bs4 import BeautifulSoup
import requests
import json

# %%
#imdb link to 100 top movie
url = "https://www.imdb.com/chart/moviemeter/?sort=nv,desc&mode=simple&page=1"
source_code = requests.get(url).text
parsed_code = BeautifulSoup(source_code, "html.parser")
#finding all td tags with class of titleColumn
first = parsed_code.find_all("td", class_ = "titleColumn")

#creating empty lists that will be appended later
ratings = []
budgets_ = []
revenues = []
movie_name = []
runtimes = []
for i in first:
    year = False
    try:
        #Finding movies with year between 2015 and 2020
        year_data = int((i.find("span", class_ = "secondaryInfo").text)[1:-1])
        if 2015<= year_data <=2020:
            year = True
        
    except:
        pass
    
    #if between 2015 and 2020, execute following code
    if year:
        print(i.find("a").text, " ", year_data)
        url2 = "https://www.imdb.com" + i.find("a")["href"]
        #getting info for each movies individual web page
        source_code2 = requests.get(url2).text
        parsed_code2 = BeautifulSoup(source_code2, "html.parser")
        second = parsed_code2.find_all("div")
        for j in second:
            found = False
            found2 = False
            txt = j.get_text()
            try:
                #finding the information that comes directly after Budget and Worldwide Gross
                budget = txt.split('Budget:$')[1].split()[0]
                revenue = txt.split('Cumulative Worldwide Gross:')[1].split()[0][1:]
                print("Budget: ", budget)
                print("Gross: ", revenue)
                found = True
                break
                
            except:
                pass
                
        try:
            #getting info from json object 
            data = json.loads(parsed_code2.find('script', type='application/ld+json').string)
            rating = data["contentRating"]
            print(rating)
        except:
            pass
        
        try:
            #findign runtimes
            fourth = parsed_code2.find_all('time')
            runtime = fourth[1].text
            print(runtime + "\n")
            found2 = True
        except:
            pass
        
        #if budget, revenue, and runtime are all found, append each list with the correct information:
        if found == True and found2 == True:
            budgets_.append(budget) #budget
            revenues.append(revenue) #revenue
            ratings.append(rating) #rating
            movie_name.append(i.find("a").text) #title
            runtimes.append(runtime) #runtime
# Out:
# Joker   2019
# Budget:  55,000,000
# Gross:  1,074,251,311
# R
# 122 min
#
# Mad Max: Fury Road   2015
# Budget:  150,000,000
# Gross:  375,274,075
# R
# 120 min
#
# Avengers: Endgame   2019
# Budget:  356,000,000
# Gross:  2,797,800,564
# PG-13
# 181 min
#
# Once Upon a Time... In Hollywood   2019
# Budget:  90,000,000
# Gross:  374,343,626
# R
# 161 min
#
# Parasite   2019
# Budget:  11,400,000
# Gross:  258,580,423
# R
# 132 min
#
# Knives Out   2019
# Budget:  40,000,000
# Gross:  311,398,301
# PG-13
# 130 min
#
# 1917   2019
# Budget:  95,000,000
# Gross:  384,792,488
# R
# 119 min
#
# Star Wars: The Rise Of Skywalker   2019
# Budget:  275,000,000
# Gross:  1,074,144,248
# PG-13
# 141 min
#
# Spider-Man: Into the Spider-Verse   2018
# Budget:  90,000,000
# Gross:  375,540,831
# PG
# 117 min
#
# Jojo Rabbit   2019
# Budget:  14,000,000
# Gross:  90,335,025
# PG-13
# 108 min
#
# The Gentlemen   2019
# Budget:  22,000,000
# Gross:  115,171,795
# R
# 113 min
#
# Tenet   2020
# Budget:  205,000,000
# Gross:  359,900,000
# PG-13
# 150 min
#
# Enola Holmes   2020
# PG-13
# 123 min
#
# Borat Subsequent Moviefilm   2020
# R
# 95 min
#
# Klaus   2019
# PG
# 96 min
#
# Bombshell   2019
# Budget:  32,000,000
# Gross:  61,404,394
# R
# 109 min
#
# Mulan   2020
# Budget:  200,000,000
# Gross:  66,800,000
# PG-13
# 115 min
#
# The Devil All the Time   2020
# R
# 138 min
#
# The Trial of the Chicago 7   2020
# R
# 129 min
#
# The Hunt   2020
# Budget:  14,000,000
# Gross:  10,891,670
# R
# 90 min
#
# Underwater   2020
# Budget:  80,000,000
# Gross:  40,882,928
# PG-13
# 95 min
#
# Peppermint   2018
# Budget:  25,000,000
# Gross:  53,918,723
# R
# 101 min
#
# The Christmas Chronicles   2018
# PG
# 104 min
#
# The Grinch   2018
# Budget:  75,000,000
# Gross:  511,782,007
# PG
# 85 min
#
# Last Christmas   2019
# Budget:  25,000,000
# Gross:  121,550,750
# PG-13
# 103 min
#
# 365 Days   2020
# TV-MA
# 114 min
#
# Dolittle   2020
# Budget:  175,000,000
# Gross:  245,802,698
# PG
# 101 min
#
# The New Mutants   2020
# Budget:  67,000,000
# Gross:  46,305,130
# PG-13
# 94 min
#
# Holidate   2020
# TV-MA
# 103 min
#
# Greenland   2020
# PG-13
# 119 min
#
# Unhinged   2020
# Budget:  33,000,000
# Gross:  42,831,465
# R
# 90 min
#
# Emma.   2020
# Budget:  10,000,000
# Gross:  25,647,469
# PG
# 124 min
#
# Ava   2020
# R
# 96 min
#
# The Witches   2020
# PG
# 106 min
#
# Mank   2020
# R
# 131 min
#
# Mosul   2019
# TV-MA
# 86 min
#
# Run   2020
# PG-13
# 90 min
#
# Hillbilly Elegy   2020
# R
# 116 min
#
# Happiest Season   2020
# PG-13
# 102 min
#
# Noelle   2019
# G
# 100 min
#
# After We Collided   2020
# R
# 105 min
#
# Freaky   2020
# Budget:  5,000,000
# Gross:  13,446,040
# R
# 102 min
#
# The Christmas Chronicles 2   2020
# PG
# 112 min
#
# Jingle Jangle: A Christmas Journey   2020
# PG
# 122 min
#
# Fatman   2020
# R
# 100 min
#
# Hard Kill   2020
# R
# 98 min
#
# The Call   2020
# 112 min
#
# Operation Christmas Drop   2020
# TV-G
# 95 min
#
# Let Him Go   2020
# R
# 113 min
#
# Uncle Frank   2020
# R
# 95 min
#
# Don't Listen   2020
# 97 min
#
# The Princess Switch: Switched Again   2020
# TV-G
# 96 min
#
# Sound of Metal   2019
# R
# 120 min
#
# The 2nd   2020
# Not Rated
# 93 min
#
# Godmothered   2020
# PG
# 110 min
#
# Superintelligence   2020
# PG
# 106 min
#
# Ammonite   2020
# R
# 120 min
#
# The Beast   2020
# TV-MA
# 97 min
#
# Life in a Year   2020
# PG-13
# 107 min
#
# Black Bear   2020
# R
# 104 min
#
# Wander   2020
# R
# 94 min
#
# The Croods: A New Age   2020
# PG
# 95 min
#
# Black Beauty   2020
# 110 min
#
# The Prom   2020
# PG-13
# 130 min
#
# The Midnight Sky   2020
# PG-13
# 122 min
#
# Wonder Woman 1984   2020
# PG-13
# 151 min
#
# Boss Level   2020
# 100 min

# %%
ratings
#creating empty dict to keep track of frequency of each rating
dict1 = {}
for i in ratings:
    if i not in dict1:
        dict1[i] = 1
    else:
        dict1[i] += 1
dict1
keys = dict1.keys()
values = dict1.values()
with plt.style.context("seaborn-paper"):
    plt.figure(figsize =(8,8))
    plt.pie(values, labels = dict1.keys(), shadow=True, startangle=90, explode = (.1,0,0),autopct='%1.1f%%')
    plt.title("Ratings of Popular Movies 2015-2020");# Look at title
    plt.xlabel("Ratings");
    plt.ylabel("Frequency");
    plt.axis('equal') 
#out of most popular movies 2015-2020, which rating appears most frequently

# %% [markdown]
# Microsoft should strong consider entering the movie industry with a film that is rated R or PG-13

# %%
import numpy as np
#create df from beautiful soup info
df = pd.DataFrame(
    {'Budgets': budgets_,
     'Gross': revenues,
     'Ratings': ratings,
     "Movie Name": movie_name,
     "Run Time": runtimes
    })

df = df.set_index("Movie Name")
#cleaning up data so budgets, runtime, and revenue can all be converted into integers
df["Budgets"] = df["Budgets"].map(lambda x: int(x.replace("," , "")))
df["Gross"] = df["Gross"].map(lambda x: int(x.replace("," , "")))
df["Run Time"] = df["Run Time"].map(lambda x: int(x.split()[0]))
#budgets and revenue divided by 1,000,000 for readability
df["Budgets"] = df["Budgets"]/1000000
df["Gross"] = df["Gross"]/1000000
sns.regplot(data=df, x="Budgets", y="Gross", color = "red");
#plt.xticks(np.arange(0,400,50))
plt.yticks(np.arange(0,3000,500))
plt.xlabel("Budgets (Millions $)")
plt.ylabel("Revenue (Millions $)")
#plotting budget and revenue relationship for beautiful soup info instead
plt.title("Budget vs. Gross Revenue");
df["ROI"] = (df["Gross"]/df["Budgets"])
df.sort_values("ROI", ascending = False)
# Out:
#                                    Budgets        Gross Ratings  Run Time  \
# Movie Name
# Parasite                              11.4   258.580423       R       132
# Joker                                 55.0  1074.251311       R       122
# Avengers: Endgame                    356.0  2797.800564   PG-13       181
# Knives Out                            40.0   311.398301   PG-13       130
# The Grinch                            75.0   511.782007      PG        85
# Jojo Rabbit                           14.0    90.335025   PG-13       108
# The Gentlemen                         22.0   115.171795       R       113
# Last Christmas                        25.0   121.550750   PG-13       103
# Spider-Man: Into the Spider-Verse     90.0   375.540831      PG       117
# Once Upon a Time... In Hollywood      90.0   374.343626       R       161
# 1917                                  95.0   384.792488       R       119
# Star Wars: The Rise Of Skywalker     275.0  1074.144248   PG-13       141
# Freaky                                 5.0    13.446040       R       102
# Emma.                                 10.0    25.647469      PG       124
# Mad Max: Fury Road                   150.0   375.274075       R       120
# Peppermint                            25.0    53.918723       R       101
# Bombshell                             32.0    61.404394       R       109
# Tenet                                205.0   359.900000   PG-13       150
# Dolittle                             175.0   245.802698      PG       101
# Unhinged                              33.0    42.831465       R        90
# The Hunt                              14.0    10.891670       R        90
# The New Mutants                       67.0    46.305130   PG-13        94
# Underwater                            80.0    40.882928   PG-13        95
# Mulan                                200.0    66.800000   PG-13       115
#
#                                          ROI
# Movie Name
# Parasite                           22.682493
# Joker                              19.531842
# Avengers: Endgame                   7.858990
# Knives Out                          7.784958
# The Grinch                          6.823760
# Jojo Rabbit                         6.452502
# The Gentlemen                       5.235082
# Last Christmas                      4.862030
# Spider-Man: Into the Spider-Verse   4.172676
# Once Upon a Time... In Hollywood    4.159374
# 1917                                4.050447
# Star Wars: The Rise Of Skywalker    3.905979
# Freaky                              2.689208
# Emma.                               2.564747
# Mad Max: Fury Road                  2.501827
# Peppermint                          2.156749
# Bombshell                           1.918887
# Tenet                               1.755610
# Dolittle                            1.404587
# Unhinged                            1.297923
# The Hunt                            0.777976
# The New Mutants                     0.691121
# Underwater                          0.511037
# Mulan                               0.334000

# %%
with plt.style.context("fast"):
    sns.regplot(data=df, x="Run Time", y="Gross", color = "orange");
    plt.yticks(np.arange(0,3500,500))
    plt.ylabel("Revenue (Millions $)")
    plt.xlabel("Run Time (Minutes)")
    plt.title("Run Time vs. Gross Revenue");
#Plotting runtime vs gross revenue for beautiful soup info

# %%
df["Run Time"].hist(color = "navy");
plt.title("Common Runtimes");

# %%
sns.regplot(data=df, x="Run Time", y="ROI", color = "green");
plt.title("Run Time vs. ROI");
plt.xlim(85,181)
#plotting runtime vs ROI for beautiful soup info
# Out:
# (85.0, 181.0)

# %%
#finding mean for each rating, could have also used groupby method
R_mean = df.loc[df["Ratings"] == "R"]["ROI"].mean()
PG13_mean = df.loc[df["Ratings"] == "PG-13"]["ROI"].mean()
PG_mean = df.loc[df["Ratings"] == "PG"]["ROI"].mean()
rating_list = ["R", "PG-13", "PG"] # or list(set(df["Ratings"]))
with plt.style.context('seaborn-bright'):
    plt.barh(rating_list, [R_mean, PG13_mean, PG_mean], color = "magenta")
    plt.xlabel("Mean ROI")
    plt.ylabel("Ratings")
    plt.title("Ratings vs. Mean ROI")
#Ratings and their mean ROI for beautiful soup data

# %%
sns.boxplot(x = df["Run Time"], color = "teal")
plt.title("Run Time Boxplot");

# %% [markdown]
# While there was less data obtained through web scraping, this data conveys the same picture as the previous data. Most common runtimes are around the two hour mark, there is a positive correlation between budget and revenue, and the rating given to a movie can definetly have an impact on its popularity.

# %% [markdown]
# # Conclusion
# - After analysis of the given data, as well as data analyzed through BeautifulSoup, there are a few assumptions that can be made. First of all, Microsoft should er on the side of producing a movie rated PG-13, or R, as these ratings accounted for a large majority of the most popular movies examined. The runtime of the movie should be around 120 minutes, but there shouldn't be that much worry if it goes over. Microsoft would be best off producing an action, adventure, or drama movie as these were the most popular genres of the top 100 rated movies (Flatiron Data). There also shouldn't be too much worry on spending a large chunk of money during the production process, as the data suggested that the more movies invest in themselves the more revenue they usually tend to recieve. Lastly, movies such as Mad Max, Paranormal Activity 4, The Gallows, and The Blair Witch Project should all be watched and studied to see how they all made over 400 times the money they invested in the production process.
